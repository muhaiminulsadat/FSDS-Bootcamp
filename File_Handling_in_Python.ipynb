# %% [markdown]
# <a href="https://colab.research.google.com/github/muhaiminulsadat/FSDS-Bootcamp/blob/main/File_Handling_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # File Handling in Python
#
# ##### Types of data used for I/O:
# - Text - '12345' as a sequence of unicode chars
# - Binary - 12345 as a sequence of bytes of its binary equivalent
#
# ##### Hence there are 2 file types to deal with
# - Text files - All program files are text files
# - Binary Files - Images,music,video,exe files
#
#
#
# ### How File I/O is done in most programming languages
#
# - Open a file
# - Read/Write data
# - Close the file

# %% [markdown]
# # Writing to a file

# %%
#if the file is not present

f = open("files/sample.txt", "w")
f.write("Hello Python")
f.close()

# %%
#if the file is not present

f = open("files/sample1.txt", "w")
f.write("Hello Python")
f.close()

# %%
f.write("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f.write("Hello")
#
# ValueError: I/O operation on closed file.

# %%
# write multiline strings
f = open('files/sample1.txt','w')
f.write('hello world')
f.write('\nhow are you?')
f.write("\nwho are you?")
f.close()

# %%
# case 2 - if the file is already present
f = open('files/sample1.txt','w')
f.write('Yo yo honey singh')
f.close()

# %%
# introducing append mode
f = open('files/sample1.txt','a')
f.write('\nI am fine')
f.close()

# %%
# write lines
L = ['hello\n','hi\n','how are you\n','I am fine']

f = open('files/sample.txt','w')
f.writelines(L)
f.close()

# %% [markdown]
# # reading from files

# %%
f = open('files/sample.txt','r')
s = f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %%
# reading upto n chars
f = open('files/sample.txt','r')
s = f.read(15)
print(s)
f.close()
# Out:
# hello
# hi
# how ar

# %%
# readline() -> to read line by line
f = open('files/sample.txt','r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hello
# hi

# %%
f = open('files/sample.txt','r')

while True:
    data = f.readline()

    if data == "":
        break
    else:
        print(data, end= "")


f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %% [markdown]
# # File Handling using Context Manager (With)

# %% [markdown]
# ### Using Context Manager (With)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we dont close it, garbage collector would close it
# - with keyword closes the file as soon as the usage is over

# %%
with open("files/sample.txt", "w") as f:
    f.write("Hello there!")

# %%
f.write("Bappy")

# %%
# read()
with open("files/sample.txt", "r") as f:
    s = f.read()
    print(s)
# Out:
# Hello there!

# %%
# readline()
with open("files/sample.txt", "r") as f:
    s = f.readline()
    print(s)
# Out:
# Hello there!

# %%
# append mode
with open("files/sample.txt", "a") as f:
    s = f.write("\nMy name is Bappy")

# %%
# moving within a file
with open("files/sample.txt", "r") as f:
    print(f.read(10))
# Out:
# Hello ther

# %%
with open("files/sample.txt", "r") as f:
    f.seek(5)
    print(f.read())
# Out:
#  there!
# My name is Bappy

# %%
with open("files/sample.txt", "r") as f:
    f.seek(5)
    print(f.tell())
# Out:
# 5

# %% [markdown]
# # Problems with working in text mode

# %% [markdown]
# - can't work with binary files like images
# - not good for other data types like int/float/list/tuples

# %%
# working with binary file
with open("files/bappy.jpg", 'r') as f:
    print(f.read())

# %%
# working with binary file
with open("files/bappy.jpg", 'rb') as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\
\x8e/;\xc3|m\x9d|\x8b\xfe\x8e\x0b\xcd]\x9d\xf9>\x86y.\x8f\x1b\xc4i\xad\xf7Z\xc9Y\xbe\xfa\\G\xf4WC8\xe7\xdc.&\xd4\xd3\xe2\x95\xcc\x87\x90K\x9dc\xfa\xad\xfb\xc1/\x0c\xa8\xb1\xddx\xce+\x13d\x8a"\x1a\xd6;qu\xde\x1f\x95\xb2\xfc\xb4\x9fp\x97\n\xa7|6\xb6\x92\xc0\xba\xa5(\xc7\x87\xd9\xc8\xb1\xbc\x9c\xc5pyJ\x97\xc7\x7f\x10),\xe6c"@:H\xd0U\xc5\x0f\xda\x8b7R\x90+h\xa9j@\xff\x00\x0e\x93\xfb.\xa3\x9b\xbe\xce\xf9;\x1b\xa6\x91\xf8L\x0e\xa0\xaa\xe5\xaea$|\x11\xd9hU\x1fd\xca\x89`\x0f\xa5\xcc\xda\x1e\xe0\tl\x91pl\xb1\xbb\xe8~[^\xe4\xfa\x0f\xb5\x9d\'\x18\x8e] \x0eLr\x7f\xaa\xd90\xd ...

# %%
# working with binary file
with open("files/bappy.jpg", 'rb') as f:
    original_file = f.read()

    with open("files/bappy_copy.jpg", "wb") as wf:
        wf.write(original_file)

# %%
# working with other data types
with open('sample.txt','w') as f:
  f.write(5)

# %%
# working with other data types
with open('files/sample.txt','w') as f:
  f.write("5")

# %%
# working with other data types
with open('files/sample.txt','r') as f:
  data = f.read()
  print(type(data))
  print(data)
# Out:
# <class 'str'>
# 5

# %%
# more complex data
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open('files/sample1.txt','w') as f:
  f.write(d)

# %%
# more complex data
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open('files/sample1.txt','w') as f:
  f.write(str(d))

# %%
with open('files/sample1.txt','r') as f:
  s = f.read()
  print(s)
  print(type(s))
# Out:
# {'name': 'Bappy', 'age': 23, 'gender': 'male'}
# <class 'str'>

# %% [markdown]
# ### Serialization and Deserialization
#
# - **Serialization** - process of converting python data types to JSON format
# - **Deserialization** - process of converting JSON to python data types
#
# #### What is JSON?
# The full form of JSON is JavaScript Object Notation.
#
# ![image.png](data:image/png;base64,...)

# %%
import json

L = [1,2,3,4,5,6]

with open("files/test.json", "w") as f:
    json.dump(L, f)

# %%
import json

with open("files/test.json", "r") as f:
    data = json.load(f)
    print(data)
    print(type(data))
# Out:
# [1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
# dict
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open("files/test.json", "w") as f:
    json.dump(d, f, indent=4)

# %%
import json

with open("files/test.json", "r") as f:
    data = json.load(f)
    print(data)
    print(type(data))
# Out:
# {'name': 'Bappy', 'age': 23, 'gender': 'male'}
# <class 'dict'>

# %%
def main():
    print("Hello Bappy")

# %% [markdown]
# # Pickling in Python

# %% [markdown]
# ### Pickling
# `Pickling` is the process whereby a Python object hierarchy is converted into a byte stream, and `unpickling` is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.

# %%
def display_info():
    return "Hi my name is Bappy and I am a Programmer"

# %%
d = display_info()

# %%
# pickle dump
import pickle
with open('files/function.pkl','wb') as f:
  pickle.dump(d,f)

# %%
# pickle load
import pickle
with open('files/function.pkl','rb') as f:
  p = pickle.load(f)
  print(p)
# Out:
# Hi my name is Bappy and I am a Programmer
